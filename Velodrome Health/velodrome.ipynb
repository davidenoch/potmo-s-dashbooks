# %%
cd potmo-s-dashbooks/
# Out:
# [Errno 2] No such file or directory: 'potmo-s-dashbooks/'
# /work/files/workspace/potmo-s-dashbooks

# %%
# %config IPCompleter.use_jedi = False
# %matplotlib inline
# %run 'startup.py'

# %%
# %%capture
# !pip install shroomdk
# %run 'query_flipside.py'

# %%
# insert sql query here
#sql = query "select blah blah"
query_flipside()
# Out:
#       max(block_timestamp)
# 0  2022-08-09 17:21:14.000

# %%
# %load seaborn_styles.py
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline

plt.style.use("ggplot");
"""  available styles: ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 
'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale',
'seaborn', 'seaborn-bright','seaborn-colorblind', 'seaborn-dark',
'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep','seaborn-muted',
'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 
'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 
'tableau-colorblind10'] """

#sns.set_context('poster'); # 'paper', 'notebook','talk', 'poster']

# %%
sns.set_style()
plt.style.use("default")

# %%
def plot_tips():
    tips = sns.load_dataset("tips")
    g = sns.lmplot(x="tip", y="total_bill", data=tips, aspect=2)
    g = (g.set_axis_labels("Tip","Total bill(USD)").
    set(xlim=(0,10),ylim=(0,100)))
    plt.title(style_use)
    plt.show(g)

# %%
sns.set_context("notebook")
print(context)
plot_tips()

# %%
#next(gen)
gen
plot_tips()
next(gen)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipykernel_303/3059461742.py in <module>
#       2 gen
#       3 plot_tips()
# ----> 4 next(gen)
#
# StopIteration:

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips = sns.load_dataset("tips")
style_list = []
# style_use_list = ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 
# 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale',
# 'seaborn', 'seaborn-bright','seaborn-colorblind', 'seaborn-dark',
# 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep','seaborn-muted',
# 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 
# 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 
# 'tableau-colorblind10']
# style_list = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
#style_list = ["white", "dark"]
for style_use in style_use_list:
    plt.style.use(style_use)
    #for style in style_list:
    #sns.set_style(style)
    g = sns.lmplot(x="tip", y="total_bill", data=tips, aspect=2)
    g = (g.set_axis_labels("Tip","Total bill(USD)").
    set(xlim=(0,10),ylim=(0,100)))
    plt.title(style_use)
    plt.show(g)
