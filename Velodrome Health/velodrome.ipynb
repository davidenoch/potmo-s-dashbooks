# %%
# %config IPCompleter.use_jedi = False
# %matplotlib inline
# %run './startup_template/startup.py'

# %%
# %%capture
# !pip install shroomdk
# %run './startup_template/query_flipside.py'

# %%
os.environ['FLIPSIDE_API']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/mo/potmo-s-dashbooks/Velodrome Health/velodrome.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mo/potmo-s-dashbooks/Velodrome%20Health/velodrome.ipynb#ch0000013?line=0'>1</a> os.environ['FLIPSIDE_API']
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py:679, in _Environ.__getitem__(self, key)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=675'>676</a>     value = self._data[self.encodekey(key)]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=676'>677</a> except KeyError:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=677'>678</a>     # raise KeyError with the original key value
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=678'>679</a>     raise KeyError(key) from None
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=679'>680</a> return self.decodevalue(value)
#
# KeyError: 'FLIPSIDE_API'

# %%
# insert sql query here
#sql = query "select blah blah"
query_flipside()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/mo/potmo-s-dashbooks/Velodrome Health/velodrome.ipynb Cell 3' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/mo/potmo-s-dashbooks/Velodrome%20Health/velodrome.ipynb#ch0000003?line=0'>1</a> # insert sql query here
#       <a href='vscode-notebook-cell:/Users/mo/potmo-s-dashbooks/Velodrome%20Health/velodrome.ipynb#ch0000003?line=1'>2</a> #sql = query "select blah blah"
# ----> <a href='vscode-notebook-cell:/Users/mo/potmo-s-dashbooks/Velodrome%20Health/velodrome.ipynb#ch0000003?line=2'>3</a> query_flipside()
#
# File ~/potmo-s-dashbooks/Velodrome Health/startup_template/query_flipside.py:7, in query_flipside(sql)
#       <a href='file:///Users/mo/potmo-s-dashbooks/Velodrome%20Health/startup_template/query_flipside.py?line=4'>5</a> import os
#       <a href='file:///Users/mo/potmo-s-dashbooks/Velodrome%20Health/startup_template/query_flipside.py?line=5'>6</a> import pandas as pd
# ----> <a href='file:///Users/mo/potmo-s-dashbooks/Velodrome%20Health/startup_template/query_flipside.py?line=6'>7</a> flipside_api = os.environ["FLIPSIDE_API"]
#       <a href='file:///Users/mo/potmo-s-dashbooks/Velodrome%20Health/startup_template/query_flipside.py?line=7'>8</a> sdk = ShroomDK(flipside_api)
#       <a href='file:///Users/mo/potmo-s-dashbooks/Velodrome%20Health/startup_template/query_flipside.py?line=8'>9</a> results = sdk.query(sql, ttl_minutes=1440)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py:679, in _Environ.__getitem__(self, key)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=675'>676</a>     value = self._data[self.encodekey(key)]
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=676'>677</a> except KeyError:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=677'>678</a>     # raise KeyError with the original key value
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=678'>679</a>     raise KeyError(key) from None
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/os.py?line=679'>680</a> return self.decodevalue(value)
#
# KeyError: 'FLIPSIDE_API'
